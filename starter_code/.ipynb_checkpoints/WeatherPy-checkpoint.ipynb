# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 639

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_report = pd.DataFrame(columns = ["City", "Cloudiness", "Country", "Date", "Humidity",
                                        "Lat", "Lng", "Max Temp", "Wind Speed"])
weather_report["City"] = cities
weather_report.head()
# Out:
#          City Cloudiness Country Date Humidity  Lat  Lng Max Temp Wind Speed
# 0      avarua        NaN     NaN  NaN      NaN  NaN  NaN      NaN        NaN
# 1   ust-kuyga        NaN     NaN  NaN      NaN  NaN  NaN      NaN        NaN
# 2     marcona        NaN     NaN  NaN      NaN  NaN  NaN      NaN        NaN
# 3     rikitea        NaN     NaN  NaN      NaN  NaN  NaN      NaN        NaN
# 4  chokurdakh        NaN     NaN  NaN      NaN  NaN  NaN      NaN        NaN

# %%
based_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
t0 = time.time()
count = 1
set_count = 1
print(f"Beginning Data Retrieval\n..........................................")

for index, row in weather_report.iterrows():
    try:
        print(f"Processing Record \033[34m {count}\033[0m of Set \033[34m {set_count}\033[0m | {row['City']}")
        count = count + 1
        city_search = row["City"]
        url = f'{based_url}appid={api_key}&q={city_search}&units={units}'
        weather_response = requests.get(url)
        weather_json = weather_response.json()
        weather_report.loc[index, "Cloudiness"] = weather_json["clouds"]["all"]
        weather_report.loc[index, "Country"] = weather_json["sys"]["country"]
        weather_report.loc[index, "Date"] = weather_json["dt"]   
        weather_report.loc[index, "Humidity"] = weather_json["main"]["humidity"]  
        weather_report.loc[index, "Max Temp"] = weather_json["main"]["temp_max"]
        weather_report.loc[index, "Lat"] = weather_json["coord"]["lat"]
        weather_report.loc[index, "Lng"] = weather_json["coord"]["lon"]
        weather_report.loc[index, "Wind Speed"] = weather_json["wind"]["speed"]
    except (KeyError, IndexError):
        print("City " + "\033[1m" + "not"+ "\033[0m"+ " found. Skipping.....")
    if count == 51:
        t1 = time.time()
        count = 1
        set_count = set_count + 1
        time.sleep(1)
        #time.sleep(60-(t1-t0))
        #t0=time.time()
# Out:
# Beginning Data Retrieval
# ..........................................
# Processing Record  1 of Set  1 | avarua
# Processing Record  2 of Set  1 | ust-kuyga
# Processing Record  3 of Set  1 | marcona
# City not found. Skipping.....
# Processing Record  4 of Set  1 | rikitea
# Processing Record  5 of Set  1 | chokurdakh
# Processing Record  6 of Set  1 | marshall
# Processing Record  7 of Set  1 | sortland
# Processing Record  8 of Set  1 | busselton
# Processing Record  9 of Set  1 | acajutla
# Processing Record  10 of Set  1 | pyay
# Processing Record  11 of Set  1 | ponta do sol
# Processing Record  12 of Set  1 | krasnoselkup
# City not found. Skipping.....
# Processing Record  13 of Set  1 | atuona
# Processing Record  14 of Set  1 | pampa
# Processing Record  15 of Set  1 | vila franca do campo
# Processing Record  16 of Set  1 | yenagoa
# Processing Record  17 of Set  1 | bluff
# Processing Record  18 of Set  1 | dolores
# Processing Record  19 of Set  1 | palmer
# Processing Record  20 of Set  1 | barrow
# Processing Record  21 of Set  1 | east london
# Processing Record  22 of Set  1 | punta arenas
# Processing Record  23 of Set  1 | kuusamo
# Processing Record  24 of Set  1 | saleaula
# City not found. Skipping.....
# Processing Record  25 of Set  1 | srednekolymsk
# Processing Record  26 of Set  1 | mataura
# Processing Record  27 of Set  1 | hilo
# Processing Record  28 of Set  1 | hermanus
# Processing Record  29 of Set  1 | denham springs
# Processing Record  30 of Set  1 | tuktoyaktuk
# Processing Record  31 of Set  1 | ushuaia
# Processing Record  32 of Set  1 | neiafu
# Processing Record  33 of Set  1 | amderma
# City not found. Skipping.....
# Processing Record  34 of Set  1 | hambantota
# Processing Record  35 of Set  1 | bathsheba
# Processing Record  36 of Set  1 | mezen
# Processing Record  37 of Set  1 | bredasdorp
# Processing Record  38 of Set  1 | christchurch
# Processing Record  39 of Set  1 | yarada
# Processing Record  40 of Set  1 | los llanos de aridane
# Processing Record  41 of Set  1 | albany
# Processing Record  42 of Set  1 | sakakah
# City not found. Skipping.....
# Processing Record  43 of Set  1 | lompoc
# Processing Record  44 of Set  1 | mamallapuram
# Processing Record  45 of Set  1 | santa barbara
# Processing Record  46 of Set  1 | abeche
# Processing Record  47 of Set  1 | fort nelson
# Processing Record  48 of Set  1 | roshchino
# Processing Record  49 of Set  1 | jamestown
# Processing Record  50 of Set  1 | shizukuishi
# Processing Record  1 of Set  2 | ituporanga
# Processing Record  2 of Set  2 | ternate
# Processing Record  3 of Set  2 | libenge
# Processing Record  4 of Set  2 | port alfred
# Processing Record  5 of Set  2 | khatanga
# Processing Record  6 of Set  2 | dzhusaly
# City not found. Skipping.....
# Processing Record  7 of Set  2 | nouadhibou
# Processing Record  8 of Set  2 | arraial do cabo
# Processing Record  9 of Set  2 | hithadhoo
# Processing Record  10 of Set  2 | chuy
# Processing Record  11 of Set  2 | mys shmidta
# City not found. Skipping.....
# Processing Record  12 of Set  2 | cape town
# Processing Record  13 of Set  2 | souillac
# Processing Record  14 of Set  2 | port lincoln
# Processing Record  15 of Set  2 | tumannyy
# City not found. Skipping.....
# Processing Record  16 of Set  2 | kaitangata
# Processing Record  17 of Set  2 | la ronge
# Processing Record  18 of Set  2 | yar-sale
# Processing Record  19 of Set  2 | pevek
# Processing Record  20 of Set  2 | quatre cocos
# Processing Record  21 of Set  2 | maykor
# Processing Record  22 of Set  2 | new norfolk
# Processing Record  23 of Set  2 | chupaca
# Processing Record  24 of Set  2 | nanning
# Processing Record  25 of Set  2 | harwich
# Processing Record  26 of Set  2 | cayenne
# Processing Record  27 of Set  2 | alugan
# Processing Record  28 of Set  2 | longyearbyen
# Processing Record  29 of Set  2 | paamiut
# Processing Record  30 of Set  2 | haibowan
# City not found. Skipping.....
# Processing Record  31 of Set  2 | tenenkou
# Processing Record  32 of Set  2 | ranfurly
# Processing Record  33 of Set  2 | tchibanga
# Processing Record  34 of Set  2 | klaksvik
# Processing Record  35 of Set  2 | thompson
# Processing Record  36 of Set  2 | hasaki
# Processing Record  37 of Set  2 | port elizabeth
# Processing Record  38 of Set  2 | marrakesh
# Processing Record  39 of Set  2 | hobart
# Processing Record  40 of Set  2 | nizhneyansk
# City not found. Skipping.....
# Processing Record  41 of Set  2 | olafsvik
# City not found. Skipping.....
# Processing Record  42 of Set  2 | beringovskiy
# Processing Record  43 of Set  2 | champerico
# Processing Record  44 of Set  2 | clovis
# Processing Record  45 of Set  2 | roma
# Processing Record  46 of Set  2 | victoria
# Processing Record  47 of Set  2 | otradnoye
# Processing Record  48 of Set  2 | kesinga
# Processing Record  49 of Set  2 | presidencia roque saenz pena
# Processing Record  50 of Set  2 | bonga
# Processing Record  1 of Set  3 | kapaa
# Processing Record  2 of Set  3 | utmanzai
# Processing Record  3 of Set  3 | geraldton
# Processing Record  4 of Set  3 | mehamn
# Processing Record  5 of Set  3 | nikolskoye
# Processing Record  6 of Set  3 | evensk
# Processing Record  7 of Set  3 | okhotsk
# Processing Record  8 of Set  3 | pervoye maya
# Processing Record  9 of Set  3 | cidreira
# Processing Record  10 of Set  3 | saskylakh
# Processing Record  11 of Set  3 | castleblayney
# Processing Record  12 of Set  3 | puerto ayora
# Processing Record  13 of Set  3 | poum
# Processing Record  14 of Set  3 | vaini
# Processing Record  15 of Set  3 | port hedland
# Processing Record  16 of Set  3 | belushya guba
# City not found. Skipping.....
# Processing Record  17 of Set  3 | haimen
# Processing Record  18 of Set  3 | meulaboh
# Processing Record  19 of Set  3 | maneadero
# City not found. Skipping.....
# Processing Record  20 of Set  3 | kajaani
# Processing Record  21 of Set  3 | berlevag
# Processing Record  22 of Set  3 | nanortalik
# Processing Record  23 of Set  3 | honiara
# Processing Record  24 of Set  3 | vila
# Processing Record  25 of Set  3 | chifeng
# Processing Record  26 of Set  3 | xiongshi
# City not found. Skipping.....
# Processing Record  27 of Set  3 | saint george
# Processing Record  28 of Set  3 | nador
# Processing Record  29 of Set  3 | harper
# Processing Record  30 of Set  3 | castro
# Processing Record  31 of Set  3 | tadine
# Processing Record  32 of Set  3 | puerto leguizamo
# Processing Record  33 of Set  3 | chengde
# Processing Record  34 of Set  3 | kabinda
# Processing Record  35 of Set  3 | dikson
# Processing Record  36 of Set  3 | severo-kurilsk
# Processing Record  37 of Set  3 | raudeberg
# Processing Record  38 of Set  3 | lasa
# Processing Record  39 of Set  3 | marawi
# Processing Record  40 of Set  3 | faanui
# Processing Record  41 of Set  3 | pangnirtung
# Processing Record  42 of Set  3 | arlit
# Processing Record  43 of Set  3 | saint-philippe
# Processing Record  44 of Set  3 | teguldet
# Processing Record  45 of Set  3 | butaritari
# Processing Record  46 of Set  3 | tuatapere
# Processing Record  47 of Set  3 | talnakh
# Processing Record  48 of Set  3 | tabuk
# Processing Record  49 of Set  3 | te anau
# Processing Record  50 of Set  3 | gazli
# Processing Record  1 of Set  4 | fort saint john
# City not found. Skipping.....
# Processing Record  2 of Set  4 | akcakoca
# Processing Record  3 of Set  4 | ko samui
# Processing Record  4 of Set  4 | pell city
# Processing Record  5 of Set  4 | sambava
# Processing Record  6 of Set  4 | lebu
# Processing Record  7 of Set  4 | taolanaro
# City not found. Skipping.....
# Processing Record  8 of Set  4 | yellowknife
# Processing Record  9 of Set  4 | goderich
# Processing Record  10 of Set  4 | vilhena
# Processing Record  11 of Set  4 | high level
# Processing Record  12 of Set  4 | ugoofaaru
# Processing Record  13 of Set  4 | agirish
# Processing Record  14 of Set  4 | ciudad guayana
# Processing Record  15 of Set  4 | coahuayana
# Processing Record  16 of Set  4 | dwarka
# Processing Record  17 of Set  4 | colares
# Processing Record  18 of Set  4 | nantucket
# Processing Record  19 of Set  4 | oromocto
# Processing Record  20 of Set  4 | grootfontein
# Processing Record  21 of Set  4 | dubrovnik
# Processing Record  22 of Set  4 | bereda
# Processing Record  23 of Set  4 | gimli
# Processing Record  24 of Set  4 | arrecife
# City not found. Skipping.....
# Processing Record  25 of Set  4 | qaanaaq
# Processing Record  26 of Set  4 | kodiak
# Processing Record  27 of Set  4 | boende
# Processing Record  28 of Set  4 | tasiilaq
# Processing Record  29 of Set  4 | finote selam
# Processing Record  30 of Set  4 | xichang
# Processing Record  31 of Set  4 | mandalgovi
# Processing Record  32 of Set  4 | bethel
# Processing Record  33 of Set  4 | wulanhaote
# City not found. Skipping.....
# Processing Record  34 of Set  4 | uarini
# Processing Record  35 of Set  4 | upernavik
# Processing Record  36 of Set  4 | fortuna
# Processing Record  37 of Set  4 | nemuro
# Processing Record  38 of Set  4 | niesky
# Processing Record  39 of Set  4 | suzun
# Processing Record  40 of Set  4 | liverpool
# Processing Record  41 of Set  4 | nhulunbuy
# Processing Record  42 of Set  4 | ostrovnoy
# Processing Record  43 of Set  4 | bambous virieux
# Processing Record  44 of Set  4 | shunyi
# Processing Record  45 of Set  4 | amga
# Processing Record  46 of Set  4 | bengkulu
# City not found. Skipping.....
# Processing Record  47 of Set  4 | panaba
# Processing Record  48 of Set  4 | jiddah
# City not found. Skipping.....
# Processing Record  49 of Set  4 | mahibadhoo
# Processing Record  50 of Set  4 | tiksi
# Processing Record  1 of Set  5 | portland
# Processing Record  2 of Set  5 | anito
# Processing Record  3 of Set  5 | belem de sao francisco
# Processing Record  4 of Set  5 | quelimane
# Processing Record  5 of Set  5 | airai
# Processing Record  6 of Set  5 | zhireken
# Processing Record  7 of Set  5 | clyde river
# Processing Record  8 of Set  5 | touros
# Processing Record  9 of Set  5 | san buenaventura
# Processing Record  10 of Set  5 | bonavista
# Processing Record  11 of Set  5 | isangel
# Processing Record  12 of Set  5 | half moon bay
# Processing Record  13 of Set  5 | umzimvubu
# City not found. Skipping.....
# Processing Record  14 of Set  5 | namibe
# Processing Record  15 of Set  5 | kyzyl-suu
# Processing Record  16 of Set  5 | sentyabrskiy
# City not found. Skipping.....
# Processing Record  17 of Set  5 | ngunguru
# Processing Record  18 of Set  5 | pacific grove
# Processing Record  19 of Set  5 | carutapera
# Processing Record  20 of Set  5 | umm lajj
# Processing Record  21 of Set  5 | bowen
# Processing Record  22 of Set  5 | narsaq
# Processing Record  23 of Set  5 | ancud
# Processing Record  24 of Set  5 | nabire
# Processing Record  25 of Set  5 | samusu
# City not found. Skipping.....
# Processing Record  26 of Set  5 | whitehorse
# Processing Record  27 of Set  5 | penzance
# Processing Record  28 of Set  5 | edd
# Processing Record  29 of Set  5 | adre
# Processing Record  30 of Set  5 | kampong thum
# Processing Record  31 of Set  5 | carnarvon
# Processing Record  32 of Set  5 | kailua
# Processing Record  33 of Set  5 | oshawa
# Processing Record  34 of Set  5 | noumea
# Processing Record  35 of Set  5 | qeshm
# Processing Record  36 of Set  5 | bad wildbad
# Processing Record  37 of Set  5 | warrington
# Processing Record  38 of Set  5 | shingu
# Processing Record  39 of Set  5 | sitka
# Processing Record  40 of Set  5 | kavieng
# Processing Record  41 of Set  5 | atwater
# Processing Record  42 of Set  5 | smithers
# Processing Record  43 of Set  5 | phan thiet
# Processing Record  44 of Set  5 | sili
# Processing Record  45 of Set  5 | mattru
# Processing Record  46 of Set  5 | turochak
# Processing Record  47 of Set  5 | tiarei
# Processing Record  48 of Set  5 | coihaique
# Processing Record  49 of Set  5 | shache
# Processing Record  50 of Set  5 | aromashevo
# Processing Record  1 of Set  6 | bella union
# Processing Record  2 of Set  6 | ribeira grande
# Processing Record  3 of Set  6 | saldanha
# Processing Record  4 of Set  6 | mitu
# Processing Record  5 of Set  6 | hofn
# Processing Record  6 of Set  6 | malwan
# City not found. Skipping.....
# Processing Record  7 of Set  6 | vestbygda
# City not found. Skipping.....
# Processing Record  8 of Set  6 | port blair
# Processing Record  9 of Set  6 | barmer
# Processing Record  10 of Set  6 | mar del plata
# Processing Record  11 of Set  6 | tuensang
# Processing Record  12 of Set  6 | college
# Processing Record  13 of Set  6 | cabo san lucas
# Processing Record  14 of Set  6 | buariki
# City not found. Skipping.....
# Processing Record  15 of Set  6 | bestobe
# Processing Record  16 of Set  6 | bandar-e torkaman
# City not found. Skipping.....
# Processing Record  17 of Set  6 | vikulovo
# Processing Record  18 of Set  6 | saint-joseph
# Processing Record  19 of Set  6 | usinsk
# Processing Record  20 of Set  6 | port hueneme
# Processing Record  21 of Set  6 | grand-lahou
# Processing Record  22 of Set  6 | tura
# Processing Record  23 of Set  6 | telixtlahuaca
# City not found. Skipping.....
# Processing Record  24 of Set  6 | perene
# Processing Record  25 of Set  6 | bahar
# Processing Record  26 of Set  6 | silistra
# Processing Record  27 of Set  6 | sorland
# Processing Record  28 of Set  6 | san vicente
# Processing Record  29 of Set  6 | codrington
# Processing Record  30 of Set  6 | tiverton
# Processing Record  31 of Set  6 | vostok
# Processing Record  32 of Set  6 | provideniya
# Processing Record  33 of Set  6 | guerrero negro
# Processing Record  34 of Set  6 | vaitupu
# City not found. Skipping.....
# Processing Record  35 of Set  6 | inirida
# Processing Record  36 of Set  6 | kirakira
# Processing Record  37 of Set  6 | narrabri
# Processing Record  38 of Set  6 | wichian buri
# Processing Record  39 of Set  6 | dingle
# Processing Record  40 of Set  6 | villamontes
# Processing Record  41 of Set  6 | le vauclin
# Processing Record  42 of Set  6 | eenhana
# Processing Record  43 of Set  6 | hay river
# Processing Record  44 of Set  6 | iqaluit
# Processing Record  45 of Set  6 | margate
# Processing Record  46 of Set  6 | belgrade
# Processing Record  47 of Set  6 | adrar
# Processing Record  48 of Set  6 | karratha
# Processing Record  49 of Set  6 | xining
# Processing Record  50 of Set  6 | businga
# Processing Record  1 of Set  7 | sayansk
# Processing Record  2 of Set  7 | carlsbad
# Processing Record  3 of Set  7 | lampazos de naranjo
# Processing Record  4 of Set  7 | majene
# Processing Record  5 of Set  7 | norman wells
# Processing Record  6 of Set  7 | galiwinku
# City not found. Skipping.....
# Processing Record  7 of Set  7 | esperance
# Processing Record  8 of Set  7 | shizuishan
# Processing Record  9 of Set  7 | hazorasp
# Processing Record  10 of Set  7 | atar
# Processing Record  11 of Set  7 | wankaner
# Processing Record  12 of Set  7 | palestine
# Processing Record  13 of Set  7 | santa marinella
# Processing Record  14 of Set  7 | kloulklubed
# Processing Record  15 of Set  7 | toba
# Processing Record  16 of Set  7 | gat
# Processing Record  17 of Set  7 | cape coast
# Processing Record  18 of Set  7 | ahuimanu
# Processing Record  19 of Set  7 | tsihombe
# City not found. Skipping.....
# Processing Record  20 of Set  7 | jiazi
# Processing Record  21 of Set  7 | torbay
# Processing Record  22 of Set  7 | davenda
# Processing Record  23 of Set  7 | labuhan
# Processing Record  24 of Set  7 | cockburn town
# Processing Record  25 of Set  7 | jahrom
# City not found. Skipping.....
# Processing Record  26 of Set  7 | najran
# Processing Record  27 of Set  7 | sao joao da barra
# Processing Record  28 of Set  7 | aykhal
# Processing Record  29 of Set  7 | mareeba
# Processing Record  30 of Set  7 | high wycombe
# Processing Record  31 of Set  7 | dawson creek
# Processing Record  32 of Set  7 | cherskiy
# Processing Record  33 of Set  7 | canico
# Processing Record  34 of Set  7 | ipixuna
# Processing Record  35 of Set  7 | linxia
# Processing Record  36 of Set  7 | chapais
# Processing Record  37 of Set  7 | hualmay
# Processing Record  38 of Set  7 | necochea
# Processing Record  39 of Set  7 | dongsheng
# Processing Record  40 of Set  7 | kambove
# Processing Record  41 of Set  7 | mahebourg
# Processing Record  42 of Set  7 | mustasaari
# Processing Record  43 of Set  7 | kangaatsiaq
# Processing Record  44 of Set  7 | ponnani
# Processing Record  45 of Set  7 | ankazobe
# Processing Record  46 of Set  7 | barentsburg
# City not found. Skipping.....
# Processing Record  47 of Set  7 | vestmannaeyjar
# Processing Record  48 of Set  7 | umba
# Processing Record  49 of Set  7 | san quintin
# Processing Record  50 of Set  7 | dong hoi
# Processing Record  1 of Set  8 | grindavik
# Processing Record  2 of Set  8 | san rafael del sur
# Processing Record  3 of Set  8 | kholodnyy
# Processing Record  4 of Set  8 | kollumerland
# City not found. Skipping.....
# Processing Record  5 of Set  8 | mason city
# Processing Record  6 of Set  8 | rocha
# Processing Record  7 of Set  8 | rawson
# Processing Record  8 of Set  8 | kruisfontein
# Processing Record  9 of Set  8 | torrington
# Processing Record  10 of Set  8 | tambul
# City not found. Skipping.....
# Processing Record  11 of Set  8 | bilma
# Processing Record  12 of Set  8 | bosaso
# Processing Record  13 of Set  8 | vuktyl
# Processing Record  14 of Set  8 | zhelyabovka
# Processing Record  15 of Set  8 | nome
# Processing Record  16 of Set  8 | phan rang
# City not found. Skipping.....
# Processing Record  17 of Set  8 | mecca
# Processing Record  18 of Set  8 | hyeres
# Processing Record  19 of Set  8 | visnes
# Processing Record  20 of Set  8 | valdez
# Processing Record  21 of Set  8 | vao
# Processing Record  22 of Set  8 | mayo
# Processing Record  23 of Set  8 | igrim
# Processing Record  24 of Set  8 | georgetown
# Processing Record  25 of Set  8 | attawapiskat
# City not found. Skipping.....
# Processing Record  26 of Set  8 | matara
# Processing Record  27 of Set  8 | katsuura
# Processing Record  28 of Set  8 | cabedelo
# Processing Record  29 of Set  8 | xiongyue
# Processing Record  30 of Set  8 | maragogi
# Processing Record  31 of Set  8 | kongoussi
# Processing Record  32 of Set  8 | comrat
# Processing Record  33 of Set  8 | manta
# Processing Record  34 of Set  8 | itaituba
# Processing Record  35 of Set  8 | louisbourg
# City not found. Skipping.....
# Processing Record  36 of Set  8 | araouane
# Processing Record  37 of Set  8 | bratsk
# Processing Record  38 of Set  8 | constitucion
# Processing Record  39 of Set  8 | nova olinda do norte
# Processing Record  40 of Set  8 | poya
# Processing Record  41 of Set  8 | fez
# Processing Record  42 of Set  8 | camana
# City not found. Skipping.....
# Processing Record  43 of Set  8 | sinnamary
# Processing Record  44 of Set  8 | nosy varika
# Processing Record  45 of Set  8 | taldan
# Processing Record  46 of Set  8 | keti bandar
# Processing Record  47 of Set  8 | sao filipe
# Processing Record  48 of Set  8 | oktyabrskoye
# Processing Record  49 of Set  8 | makakilo city
# Processing Record  50 of Set  8 | cacador
# Processing Record  1 of Set  9 | padang
# Processing Record  2 of Set  9 | ryotsu
# Processing Record  3 of Set  9 | suntar
# Processing Record  4 of Set  9 | inuvik
# Processing Record  5 of Set  9 | kahului
# Processing Record  6 of Set  9 | ust-maya
# Processing Record  7 of Set  9 | bodden town
# Processing Record  8 of Set  9 | vestmanna
# Processing Record  9 of Set  9 | big spring
# Processing Record  10 of Set  9 | chicama
# Processing Record  11 of Set  9 | jamtara
# Processing Record  12 of Set  9 | ilovita
# Processing Record  13 of Set  9 | dallas
# Processing Record  14 of Set  9 | patacamaya
# Processing Record  15 of Set  9 | grand river south east
# City not found. Skipping.....
# Processing Record  16 of Set  9 | flin flon
# Processing Record  17 of Set  9 | virginia beach
# Processing Record  18 of Set  9 | niquero
# Processing Record  19 of Set  9 | richards bay
# Processing Record  20 of Set  9 | hamilton
# Processing Record  21 of Set  9 | lobau
# Processing Record  22 of Set  9 | dujuma
# City not found. Skipping.....
# Processing Record  23 of Set  9 | odweyne
# City not found. Skipping.....
# Processing Record  24 of Set  9 | abu samrah
# Processing Record  25 of Set  9 | piacabucu
# Processing Record  26 of Set  9 | mikhaylovsk
# Processing Record  27 of Set  9 | palu
# Processing Record  28 of Set  9 | vangaindrano
# Processing Record  29 of Set  9 | palana
# Processing Record  30 of Set  9 | huambo
# Processing Record  31 of Set  9 | vandra
# Processing Record  32 of Set  9 | aden
# Processing Record  33 of Set  9 | lata
# Processing Record  34 of Set  9 | jinka
# Processing Record  35 of Set  9 | san policarpo
# Processing Record  36 of Set  9 | kyshtovka
# Processing Record  37 of Set  9 | potosi
# Processing Record  38 of Set  9 | maxixe
# Processing Record  39 of Set  9 | san fernando
# Processing Record  40 of Set  9 | soe
# Processing Record  41 of Set  9 | grants
# Processing Record  42 of Set  9 | panapakkam
# City not found. Skipping.....
# Processing Record  43 of Set  9 | hervey bay
# Processing Record  44 of Set  9 | imbituba
# Processing Record  45 of Set  9 | antonina
# Processing Record  46 of Set  9 | eyl
# Processing Record  47 of Set  9 | nushki
# Processing Record  48 of Set  9 | duiwelskloof
# Processing Record  49 of Set  9 | tornio
# Processing Record  50 of Set  9 | madingou
# Processing Record  1 of Set  10 | reconquista
# Processing Record  2 of Set  10 | dawlatabad
# Processing Record  3 of Set  10 | bargal
# City not found. Skipping.....
# Processing Record  4 of Set  10 | alofi
# Processing Record  5 of Set  10 | sorong
# Processing Record  6 of Set  10 | flinders
# Processing Record  7 of Set  10 | kamenskoye
# City not found. Skipping.....
# Processing Record  8 of Set  10 | andenes
# City not found. Skipping.....
# Processing Record  9 of Set  10 | nerchinsk
# Processing Record  10 of Set  10 | vanimo
# Processing Record  11 of Set  10 | gonen
# Processing Record  12 of Set  10 | kaeo
# Processing Record  13 of Set  10 | bilibino
# Processing Record  14 of Set  10 | qurayyat
# City not found. Skipping.....
# Processing Record  15 of Set  10 | kearney
# Processing Record  16 of Set  10 | ibipeba
# Processing Record  17 of Set  10 | kalaleh
# Processing Record  18 of Set  10 | mergui
# City not found. Skipping.....
# Processing Record  19 of Set  10 | auki
# Processing Record  20 of Set  10 | zharkent
# Processing Record  21 of Set  10 | kamuli
# Processing Record  22 of Set  10 | canmore
# Processing Record  23 of Set  10 | binzhou
# Processing Record  24 of Set  10 | aldan
# Processing Record  25 of Set  10 | bellmead
# Processing Record  26 of Set  10 | porbandar
# Processing Record  27 of Set  10 | mount darwin
# Processing Record  28 of Set  10 | hobyo
# Processing Record  29 of Set  10 | mokhsogollokh
# Processing Record  30 of Set  10 | kidal
# Processing Record  31 of Set  10 | yumen
# Processing Record  32 of Set  10 | mount pleasant
# Processing Record  33 of Set  10 | nayoro
# Processing Record  34 of Set  10 | lagoa
# Processing Record  35 of Set  10 | zhoukou
# Processing Record  36 of Set  10 | tambovka
# Processing Record  37 of Set  10 | namatanai
# Processing Record  38 of Set  10 | qurbus
# Processing Record  39 of Set  10 | buraydah
# Processing Record  40 of Set  10 | bayji
# Processing Record  41 of Set  10 | mayya
# Processing Record  42 of Set  10 | sarankhola
# Processing Record  43 of Set  10 | sola
# Processing Record  44 of Set  10 | tolbazy
# Processing Record  45 of Set  10 | conde
# Processing Record  46 of Set  10 | asfi
# City not found. Skipping.....
# Processing Record  47 of Set  10 | brugg
# Processing Record  48 of Set  10 | nioro
# Processing Record  49 of Set  10 | marsh harbour
# Processing Record  50 of Set  10 | qaqortoq
# Processing Record  1 of Set  11 | at-bashi
# Processing Record  2 of Set  11 | santa clarita
# Processing Record  3 of Set  11 | port macquarie
# Processing Record  4 of Set  11 | tanabe
# Processing Record  5 of Set  11 | ajdabiya
# Processing Record  6 of Set  11 | barcelos
# Processing Record  7 of Set  11 | kargasok
# Processing Record  8 of Set  11 | laguna beach
# Processing Record  9 of Set  11 | turukhansk
# Processing Record  10 of Set  11 | grimshaw
# Processing Record  11 of Set  11 | oneonta
# Processing Record  12 of Set  11 | pattoki
# Processing Record  13 of Set  11 | clearwater
# Processing Record  14 of Set  11 | jiayuguan
# Processing Record  15 of Set  11 | seremban
# Processing Record  16 of Set  11 | nurota
# Processing Record  17 of Set  11 | dawei
# Processing Record  18 of Set  11 | flagstaff
# Processing Record  19 of Set  11 | qatana
# Processing Record  20 of Set  11 | vila do maio
# Processing Record  21 of Set  11 | patea
# Processing Record  22 of Set  11 | tomohon
# Processing Record  23 of Set  11 | unity
# Processing Record  24 of Set  11 | lincoln
# Processing Record  25 of Set  11 | feicheng
# Processing Record  26 of Set  11 | pastavy
# Processing Record  27 of Set  11 | mount gambier
# Processing Record  28 of Set  11 | port hardy
# Processing Record  29 of Set  11 | safranbolu
# Processing Record  30 of Set  11 | sarkand
# Processing Record  31 of Set  11 | gudivada
# Processing Record  32 of Set  11 | lorengau
# Processing Record  33 of Set  11 | alyangula
# Processing Record  34 of Set  11 | cooma
# Processing Record  35 of Set  11 | bolungarvik
# City not found. Skipping.....
# Processing Record  36 of Set  11 | khani
# Processing Record  37 of Set  11 | umm kaddadah
# Processing Record  38 of Set  11 | solnechnyy
# Processing Record  39 of Set  11 | nouakchott
# Processing Record  40 of Set  11 | orlik
# Processing Record  41 of Set  11 | caravelas
# Processing Record  42 of Set  11 | emerald
# Processing Record  43 of Set  11 | gombe
# Processing Record  44 of Set  11 | surt
# Processing Record  45 of Set  11 | taoudenni
# Processing Record  46 of Set  11 | kurchum
# Processing Record  47 of Set  11 | palabuhanratu
# City not found. Skipping.....
# Processing Record  48 of Set  11 | sibolga
# Processing Record  49 of Set  11 | porto belo
# Processing Record  50 of Set  11 | roald
# Processing Record  1 of Set  12 | wuwei
# Processing Record  2 of Set  12 | hulan
# Processing Record  3 of Set  12 | nea karvali
# Processing Record  4 of Set  12 | plettenberg bay
# Processing Record  5 of Set  12 | castiglion fiorentino
# Processing Record  6 of Set  12 | ust-omchug
# Processing Record  7 of Set  12 | tres picos
# Processing Record  8 of Set  12 | atambua
# Processing Record  9 of Set  12 | presque isle
# Processing Record  10 of Set  12 | ankazoabo
# Processing Record  11 of Set  12 | severnoye
# Processing Record  12 of Set  12 | kapit
# Processing Record  13 of Set  12 | yinchuan
# Processing Record  14 of Set  12 | sao gabriel da cachoeira
# Processing Record  15 of Set  12 | boa vista
# Processing Record  16 of Set  12 | himora
# City not found. Skipping.....
# Processing Record  17 of Set  12 | pasighat
# Processing Record  18 of Set  12 | illoqqortoormiut
# City not found. Skipping.....
# Processing Record  19 of Set  12 | lumphat
# Processing Record  20 of Set  12 | novoagansk
# Processing Record  21 of Set  12 | riyadh
# Processing Record  22 of Set  12 | mihail kogalniceanu
# Processing Record  23 of Set  12 | muisne
# Processing Record  24 of Set  12 | kurilsk
# Processing Record  25 of Set  12 | broome
# Processing Record  26 of Set  12 | muros
# Processing Record  27 of Set  12 | tsiroanomandidy
# Processing Record  28 of Set  12 | san javier
# Processing Record  29 of Set  12 | gari
# Processing Record  30 of Set  12 | lalmohan
# Processing Record  31 of Set  12 | altus
# Processing Record  32 of Set  12 | ust-kamchatsk
# City not found. Skipping.....
# Processing Record  33 of Set  12 | deder
# Processing Record  34 of Set  12 | saint anthony
# Processing Record  35 of Set  12 | saint-augustin
# Processing Record  36 of Set  12 | mporokoso
# Processing Record  37 of Set  12 | san cristobal
# Processing Record  38 of Set  12 | altay
# Processing Record  39 of Set  12 | yulara
# Processing Record  40 of Set  12 | bissau
# Processing Record  41 of Set  12 | zavetnoye
# Processing Record  42 of Set  12 | qianan
# Processing Record  43 of Set  12 | pemba
# Processing Record  44 of Set  12 | lhokseumawe
# Processing Record  45 of Set  12 | cairns
# Processing Record  46 of Set  12 | abu zabad
# Processing Record  47 of Set  12 | tucuman
# Processing Record  48 of Set  12 | tilichiki
# Processing Record  49 of Set  12 | mbinga
# Processing Record  50 of Set  12 | buritizeiro
# Processing Record  1 of Set  13 | benjamin hill
# Processing Record  2 of Set  13 | ballina
# Processing Record  3 of Set  13 | laguna
# Processing Record  4 of Set  13 | vrangel
# Processing Record  5 of Set  13 | kalmunai
# Processing Record  6 of Set  13 | jumla
# Processing Record  7 of Set  13 | wattegama
# Processing Record  8 of Set  13 | raurkela
# City not found. Skipping.....
# Processing Record  9 of Set  13 | walvis bay
# Processing Record  10 of Set  13 | sabang
# Processing Record  11 of Set  13 | yining
# Processing Record  12 of Set  13 | palampur
# Processing Record  13 of Set  13 | micheweni
# Processing Record  14 of Set  13 | yeppoon
# Processing Record  15 of Set  13 | egvekinot
# Processing Record  16 of Set  13 | new bern
# Processing Record  17 of Set  13 | shelabolikha
# Processing Record  18 of Set  13 | campbell river
# Processing Record  19 of Set  13 | nuuk
# Processing Record  20 of Set  13 | grand gaube
# Processing Record  21 of Set  13 | omboue
# Processing Record  22 of Set  13 | mananara
# City not found. Skipping.....
# Processing Record  23 of Set  13 | avera
# Processing Record  24 of Set  13 | luderitz
# Processing Record  25 of Set  13 | palauig
# Processing Record  26 of Set  13 | unai
# Processing Record  27 of Set  13 | sangin
# Processing Record  28 of Set  13 | ahipara
# Processing Record  29 of Set  13 | dengzhou
# Processing Record  30 of Set  13 | bemidji
# Processing Record  31 of Set  13 | tautira
# Processing Record  32 of Set  13 | fairbanks
# Processing Record  33 of Set  13 | traiguen
# Processing Record  34 of Set  13 | terracina
# Processing Record  35 of Set  13 | charters towers
# Processing Record  36 of Set  13 | westport
# Processing Record  37 of Set  13 | simao
# Processing Record  38 of Set  13 | bay roberts
# Processing Record  39 of Set  13 | kontagora

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_report.to_csv(output_data_file)
weather_report.count()
# Out:
# City          639
# Cloudiness    583
# Country       583
# Date          583
# Humidity      583
# Lat           583
# Lng           583
# Max Temp      583
# Wind Speed    583
# dtype: int64

# %%
weather_report.head()
# Out:
#          City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0      avarua         38      CK  1562033895       60 -21.21 -159.78     73.4
# 1   ust-kuyga        100      RU  1562033951       86     70  135.55    44.74
# 2     marcona        NaN     NaN         NaN      NaN    NaN     NaN      NaN
# 3     rikitea        100      PF  1562033951       71 -23.12 -134.97    69.25
# 4  chokurdakh        100      RU  1562033870       55  70.62   147.9    54.93
#
#   Wind Speed
# 0      10.29
# 1       5.86
# 2        NaN
# 3      16.37
# 4       9.62

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_report["Lat"], weather_report["Max Temp"], marker = "o", facecolors = "blue",
           edgecolors = "black", alpha = 0.5)
plt.title(f'City Latitude vs. Max Temperature ({datetime.now().date().strftime("%m/%d/%y")})')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("../output_data/City_Latitude_vs_Max_Temperature")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_report["Lat"], weather_report["Humidity"], marker = "o", facecolors = "teal",
           edgecolors = "black", alpha = 0.5)
plt.title(f'City Latitude vs. Humidity ({datetime.now().date().strftime("%m-%d-%y")})')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("../output_data/City_Latitude_vs_Humidity")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_report["Lat"], weather_report["Cloudiness"], marker = "o", facecolors = "steelblue",
           edgecolors = "black", alpha = 0.5)
plt.title(f'City Latitude vs. Cloudiness ({datetime.now().date().strftime("%m-%d-%y")})')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("../output_data/City_Latitude_vs_Cloudiness")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_report["Lat"], weather_report["Wind Speed"], marker = "o", facecolors = "dodgerblue",
           edgecolors = "black", alpha = 0.5)
plt.title(f'City Latitude vs. Wind Speed ({datetime.now().date().strftime("%m-%d-%y")})')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("../output_data/City_Latitude_vs_Wind_Speed")
plt.show()
